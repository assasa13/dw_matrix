# %%
 from keras.applications.resnet50 import ResNet50, decode_predictions, preprocess_input
 from keras.preprocessing import image
 import numpy as np

 import requests
 from io import BytesIO
 from PIL import Image

# %%
model = ResNet50(weights='imagenet') # wczytujemy już wytrenowany model
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4479: The name tf.truncated_normal is deprecated. Please use tf.random.truncated_normal instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# ...

# %% [markdown]
# ![](https://www.rd.com/wp-content/uploads/2019/11/cat-10-e1573844975155-768x519.jpg)

# %%
url_img = 'https://www.rd.com/wp-content/uploads/2019/11/cat-10-e1573844975155-768x519.jpg'

response = requests.get(url_img)
img = Image.open (BytesIO(response.content))
# Do modelu trzeba przekazać obraz 224x224 !!
img = img.resize((224, 224))

# %%
# Konwertujemy zdjęcie do tablicy (0-255) : (ilosc- u nas pojedyncze zdjecie, rozmiar, rozmiar, ilosc_kanałów)
X = image.img_to_array(img)
X = np.expand_dims(X, axis=0)
X.shape
# Out:
# (1, 224, 224, 3)

# %%
y_pred = model.predict(X)

# %%
decode_predictions(y_pred, top=3) # Do tych 3 rodzajów kotów jest najbardziej podobny
# Out:
# ...
# 40960/35363 [==================================] - 0s 0us/step
# [[('n02123045', 'tabby', 0.71804625),
#   ('n02123159', 'tiger_cat', 0.112326786),
#   ('n02124075', 'Egyptian_cat', 0.10401179)]]

# %%
# !git config --global user.email "asiastrug1997@vp.pl"
# !git config --global user.name "Joanna"
# !git add Data_Workshop_Challenges/Week_Two/challenge_day2.ipynb.ipynb
# !git commit -m "Adding day2 from Data Challenge"
# !git push -u origin master
# Out:
# fatal: pathspec 'Data_Workshop_Challenges/Week_Two/challenge_day2.ipynb.ipynb' did not match any files
# On branch master
# Your branch is up to date with 'origin/master'.
#
# Changes not staged for commit:
# 	modified:   Data_Workshop_Challenges/Week_One/challenge_day5.ipynb
# 	modified:   matrix_one/day3.ipynb
# 	modified:   matrix_one/day4.ipynb
# 	modified:   matrix_one/day5.ipynb
#
# Untracked files:
# 	Data_Workshop_Challenges/Week_Two/
# 	matrix_one/day4_meta.ipynb
#
# no changes added to commit
# Branch 'master' set up to track remote branch 'master' from 'origin'.
# Everything up-to-date
